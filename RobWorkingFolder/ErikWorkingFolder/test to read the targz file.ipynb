# %%
import ema_workbench

# %%
experiments, outcomes = ema_workbench.util.utilities.load_results("results15000.tar.gz")

# %%
experiments
# Out:
#        A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                         49.0  174.561114      10.0   0.832788  311.897855
# 1                         50.0  318.478026      10.0   0.973455  266.946830
# 2                         32.0  250.512041      10.0   0.897401  272.500413
# 3                         80.0  321.405757       1.5   0.716502  266.588542
# 4                         60.0   76.990266      10.0   0.571207  102.617975
# 5                        116.0   52.174631       1.0   0.425527  145.363142
# 6                         77.0  115.658419       1.0   0.556801  124.935831
# 7                         97.0  192.322011       1.0   0.229761   33.195422
# 8                         82.0  301.303813       1.0   0.458794  116.734897
# 9                         68.0   84.051297       1.0   0.580329  253.956758
# 10                        55.0  290.330330       1.5   0.613295  184.496028
# ...
