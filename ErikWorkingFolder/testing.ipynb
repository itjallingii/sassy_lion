# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

from ema_workbench import (Model, CategoricalParameter, ScalarOutcome, 
                           TimeSeriesOutcome, IntegerParameter, RealParameter,
                           MultiprocessingEvaluator, ema_logging,
                           perform_experiments, SequentialEvaluator)

from ema_workbench.analysis import prim

from ema_workbench.util.utilities import load_results

def load_tar(dike_names):
    results = {}
    for name in dike_names:
        results[name] = load_results('{}_results.tar.gz'.format(name))
    return results

if __name__ == '__main__':
    ema_logging.log_to_stderr(ema_logging.INFO)

    dike_names = ['A.1','A.2','A.3','A.4','A.5']
    results = load_tar(dike_names)
    print(results)
# Out:
# D:\Anaconda\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# D:\Anaconda\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# D:\Anaconda\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# [MainProcess/INFO] results loaded succesfully from C:\Users\epron\Dropbox\EPA1361\sassy_lion\ErikWorkingFolder\A.1_results.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\epron\Dropbox\EPA1361\sassy_lion\ErikWorkingFolder\A.2_results.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\epron\Dropbox\EPA1361\sassy_lion\ErikWorkingFolder\A.3_results.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\epron\Dropbox\EPA1361\sassy_lion\ErikWorkingFolder\A.4_results.tar.gz
# [MainProcess/INFO] results loaded succesfully from C:\Users\epron\Dropbox\EPA1361\sassy_lion\ErikWorkingFolder\A.5_results.tar.gz
# {'A.1': (   A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                     33.0  181.166737       1.0   0.430187  107.503288
# 1                     97.0  345.654116       1.5   0.814437  329.797049
# 2                     33.0  181.166737       1.0   0.430187  107.503288
# 3                     97.0  345.654116       1.5   0.814437  329.797049
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0      10.0   0.937278   42.350121       1.5   0.333833  ...
# 1       1.5   0.381110  286.665833       1.5   0.606273  ...
# 2      10.0   0.937278   42.350121       1.5   0.333833  ...
# 3       1.5   0.381110  286.665833       1.5   0.606273  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                 2.0                6.0                10.0
# 1                 2.0                6.0                10.0
# 2                 6.0                3.0                 1.0
# 3                 6.0                3.0                 1.0
#
#    A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2 EWS_DaysToThreat  \
# 0                 2.0                0.0                 5.0              1.0
# 1                 2.0                0.0                 5.0              1.0
# 2                 7.0               10.0                 9.0              4.0
# 3                 7.0               10.0                 9.0              4.0
#
#   scenario policy     model
# 0        0      0  dikesnet
# 1        1      0  dikesnet
# 2        0      1  dikesnet
# 3        1      1  dikesnet
#
# [4 rows x 53 columns], {'Expected Annual Damage A1': array([0., 0., 0., 0.]), 'Investment Costs A1': array([3.08561700e+08, 3.08561700e+08, 1.65182777e+08, 1.65182777e+08]), 'Expected Number of Deaths in A1': array([0., 0., 0., 0.])}), 'A.2': (   A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                     41.0  242.251826       1.5   0.756562  206.313496
# 1                    113.0  163.779711      10.0   0.431008  142.479491
# 2                     41.0  242.251826       1.5   0.756562  206.313496
# 3                    113.0  163.779711      10.0   0.431008  142.479491
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0      10.0   0.646542   99.701048      10.0   0.641405  ...
# 1       1.0   0.345902  329.071300       1.5   0.211075  ...
# 2      10.0   0.646542   99.701048      10.0   0.641405  ...
# 3       1.0   0.345902  329.071300       1.5   0.211075  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                 2.0                9.0                 6.0
# 1                 2.0                9.0                 6.0
# 2                 6.0                2.0                 1.0
# 3                 6.0                2.0                 1.0
#
#    A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2 EWS_DaysToThreat  \
# 0                 8.0                3.0                 2.0              0.0
# 1                 8.0                3.0                 2.0              0.0
# 2                 0.0                8.0                 6.0              3.0
# 3                 0.0                8.0                 6.0              3.0
#
#   scenario policy     model
# 0        2      2  dikesnet
# 1        3      2  dikesnet
# 2        2      3  dikesnet
# 3        3      3  dikesnet
#
# [4 rows x 53 columns], {'Expected Annual Damage A2': array([      0.        , 3970345.96545388,       0.        ,
#              0.        ]), 'Investment Costs A2': array([2.85200127e+08, 2.85200127e+08, 1.98269928e+08, 1.98269928e+08]), 'Expected Number of Deaths in A2': array([0.       , 0.0036099, 0.       , 0.       ])}), 'A.3': (   A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                     35.0  343.376328      10.0   0.586438  285.508767
# 1                     86.0  176.722121       1.0   0.206091   31.235893
# 2                     35.0  343.376328      10.0   0.586438  285.508767
# 3                     86.0  176.722121       1.0   0.206091   31.235893
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0       1.0   0.688001  226.869541       1.5   0.651655  ...
# 1      10.0   0.311256  169.690799      10.0   0.413679  ...
# 2       1.0   0.688001  226.869541       1.5   0.651655  ...
# 3      10.0   0.311256  169.690799      10.0   0.413679  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                 4.0                7.0                 5.0
# 1                 4.0                7.0                 5.0
# 2                 7.0                4.0                 5.0
# 3                 7.0                4.0                 5.0
#
#    A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2 EWS_DaysToThreat  \
# 0                10.0               10.0                 3.0              4.0
# 1                10.0               10.0                 3.0              4.0
# 2                 0.0                2.0                 6.0              2.0
# 3                 0.0                2.0                 6.0              2.0
#
#   scenario policy     model
# 0        4      4  dikesnet
# 1        5      4  dikesnet
# 2        4      5  dikesnet
# 3        5      5  dikesnet
#
# [4 rows x 53 columns], {'Expected Annual Damage A3': array([0.00000000e+00, 0.00000000e+00, 2.34971459e+06, 1.86981422e+08]), 'Investment Costs A3': array([1.99018285e+08, 1.99018285e+08, 7.06512995e+07, 7.06512995e+07]), 'Expected Number of Deaths in A3': array([0.        , 0.        , 0.00039397, 0.01814577])}), 'A.4': (   A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                     58.0  185.615059       1.0   0.135264  148.539578
# 1                     78.0  230.213436      10.0   0.920806  301.749891
# 2                     58.0  185.615059       1.0   0.135264  148.539578
# 3                     78.0  230.213436      10.0   0.920806  301.749891
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0      10.0   0.781871   44.366213       1.5   0.323241  ...
# 1       1.0   0.117549  336.734246      10.0   0.709991  ...
# 2      10.0   0.781871   44.366213       1.5   0.323241  ...
# 3       1.0   0.117549  336.734246      10.0   0.709991  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                 8.0                3.0                 9.0
# 1                 8.0                3.0                 9.0
# 2                 1.0               10.0                 1.0
# 3                 1.0               10.0                 1.0
#
#    A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2 EWS_DaysToThreat  \
# 0                 3.0                6.0                 4.0              0.0
# 1                 3.0                6.0                 4.0              0.0
# 2                 9.0                0.0                 9.0              3.0
# 3                 9.0                0.0                 9.0              3.0
#
#   scenario policy     model
# 0        6      6  dikesnet
# 1        7      6  dikesnet
# 2        6      7  dikesnet
# 3        7      7  dikesnet
#
# [4 rows x 53 columns], {'Expected Annual Damage A4': array([0., 0., 0., 0.]), 'Investment Costs A4': array([1.20059094e+08, 1.20059094e+08, 1.24982685e+08, 1.24982685e+08]), 'Expected Number of Deaths in A4': array([0., 0., 0., 0.])}), 'A.5': (   A.0_ID flood wave shape   A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                     46.0  236.92608       1.5   0.185421  253.090905
# 1                     98.0  111.94390       1.5   0.598261  136.389874
# 2                     46.0  236.92608       1.5   0.185421  253.090905
# 3                     98.0  111.94390       1.5   0.598261  136.389874
#
#   A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0       1.5   0.087970  224.898760       1.5   0.896615  ...
# 1      10.0   0.881395  151.381167      10.0   0.217001  ...
# 2       1.5   0.087970  224.898760       1.5   0.896615  ...
# 3      10.0   0.881395  151.381167      10.0   0.217001  ...
#
#    A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                 4.0                4.0                 9.0
# 1                 4.0                4.0                 9.0
# 2                 8.0                6.0                 1.0
# 3                 8.0                6.0                 1.0
#
#    A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2 EWS_DaysToThreat  \
# 0                 6.0                2.0                 7.0              4.0
# 1                 6.0                2.0                 7.0              4.0
# 2                 0.0                5.0                 4.0              1.0
# 3                 0.0                5.0                 4.0              1.0
#
#   scenario policy     model
# 0        8      8  dikesnet
# 1        9      8  dikesnet
# 2        8      9  dikesnet
# 3        9      9  dikesnet
#
# [4 rows x 53 columns], {'Expected Annual Damage A5': array([       0.        ,        0.        , 30810192.70423014,
#               0.        ]), 'Investment Costs A5': array([1.31834239e+08, 1.31834239e+08, 7.61596890e+07, 7.61596890e+07]), 'Expected Number of Deaths in A5': array([0.       , 0.       , 0.0074365, 0.       ])})}

# %%
from ema_workbench import MultiprocessingEvaluator

# %%
MultiprocessingEvaluator??
